# %%
class Animal1:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10

# %%
tom=Animal1('tom')
print(tom.name)
tom.__dict__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8b4f57d9fa7c> in <module>
#       1 tom=Animal1('tom')
# ----> 2 print(tom.name)
#       3 tom.__dict__
#
# AttributeError: 'Animal1' object has no attribute 'name'

# %% [markdown]
# ## 定义

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Cat('tom')
print(tom.name)
print(tom.shout())
# Out:
# tom
# miao
# None

# %%
tom.__dict__
# Out:
# {'_name': 'tom', '_Animal__age': 10}

# %%
jerry=Animal('jerry')

# %%
jerry.__dict__

# %%
jerry._Animal__age

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Carfield('tom')
print(tom.x)
print(tom.__dict__)
print(Carfield.__dict__)
print(Cat.__dict__)
print(Animal.__dict__)
# Out:
# cat
# {'catname': 'tom'}
# {'__module__': '__main__', '__doc__': None}
# {'__module__': '__main__', 'x': 'cat', '__init__': <function Cat.__init__ at 0x000000000684FAE8>, 'shout': <function Cat.shout at 0x000000000684FB70>, '__doc__': None}
# {'__module__': '__main__', 'x': 123, '__init__': <function Animal.__init__ at 0x000000000684FE18>, 'name': <property object at 0x0000000006855E58>, 'shout': <function Animal.shout at 0x000000000684FBF8>, '__dict__': <attribute '__dict__' of 'Animal' objects>, '__weakref__': <attribute '__weakref__' of 'Animal' objects>, '__doc__': None}

# %% [markdown]
# ##  访问控制

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Cat('tom')
print(tom.name)
print(tom.shout())
print(tom.__dict__)
# Out:
# tom
# miao
# None
# {'_name': 'tom', '_Animal__age': 10}

# %%
gf=Carfield('tom')
print(gf.__dict__)
print(Carfield.__dict__)
print(Cat.__dict__)
print(Animal.__dict__)
# Out:
# {'_name': 'tom', '_Animal__age': 10}
# {'__module__': '__main__', '__doc__': None}
# {'__module__': '__main__', 'x': 'cat', 'shout': <function Cat.shout at 0x000000000684FC80>, '__doc__': None}
# {'__module__': '__main__', 'x': 123, '__init__': <function Animal.__init__ at 0x000000000684F488>, 'name': <property object at 0x00000000068456D8>, 'shout': <function Animal.shout at 0x000000000684F8C8>, '__dict__': <attribute '__dict__' of 'Animal' objects>, '__weakref__': <attribute '__weakref__' of 'Animal' objects>, '__doc__': None}

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        self.catname=name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Carfield('tom')
#print(tom.name)
print(tom.__dict__)
print(Carfield.__dict__)
print(Cat.__dict__)
print(Animal.__dict__)
print('*********************')
print('tom.mro={}'.format(tom.__class__.__mro__))
# Out:
# {'catname': 'tom'}
# {'__module__': '__main__', '__doc__': None}
# {'__module__': '__main__', 'x': 'cat', '__init__': <function Cat.__init__ at 0x000000000684FAE8>, 'shout': <function Cat.shout at 0x000000000684FB70>, '__doc__': None}
# {'__module__': '__main__', 'x': 123, '__init__': <function Animal.__init__ at 0x000000000684FE18>, 'name': <property object at 0x0000000006855E58>, 'shout': <function Animal.shout at 0x000000000684FBF8>, '__dict__': <attribute '__dict__' of 'Animal' objects>, '__weakref__': <attribute '__weakref__' of 'Animal' objects>, '__doc__': None}
# *********************
# tom.mro=(<class '__main__.Carfield'>, <class '__main__.Cat'>, <class '__main__.Animal'>, <class 'object'>)

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')
    def eat(self):
        print('{}'.format(self.__class__.__name__))

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        self._name=name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom = Cat('tom')
tom.eat()
# Out:
# Cat

# %%
tom=Carfield('tom')
tom.eat()
#print(tom.name)
print(tom.__dict__)
print(Carfield.__dict__)
print(Cat.__dict__)
# Out:
# Carfield
# {'_name': 'tom'}
# {'__module__': '__main__', '__doc__': None}
# {'__module__': '__main__', 'x': 'cat', '__init__': <function Cat.__init__ at 0x000000000684F400>, 'shout': <function Cat.shout at 0x000000000684F048>, '__doc__': None}

# %%
class Animal:
    x=123
    def __init__(self,name,age=10):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name): 
        Animal.__init__(self,name)
        self.catname=name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')

# %%
cat.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10, 'catname': 'jerry'}

# %%
cat.name
# Out:
# 'jerry'

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        Animal.__init__(self,name)
        self._name='cat'+name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'catjerry', '_Animal__age': 10}

# %%
cat.name
# Out:
# 'catjerry'

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        Animal.__init__(self,name)#注意上下两个顺序不一样
        self._name='cat'+name
        
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'catjerry', '_Animal__age': 10}

# %%
cat.name
# Out:
# 'catjerry'

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        self._name='cat'+name
        Animal.__init__(self,name)#注意上下两个顺序不一样
    def shout(self):
        print('miao')
        Animal.__init__(self,'abc')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10}

# %%
cat.shout()
# Out:
# miao

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        super().__init__(name) #与下面方式等价
        #Animal.__init__(self,name)#注意上下两个顺序不一样
        self._name='cat'+name
        self.__age=20
        
    def shout(self):
        print('miao')
        Animal.__init__(self,name)

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
print(cat.name, cat.age)
# Out:
# catjerry 10

# %%
Cat.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'x': 'cat',
#               '__init__': <function __main__.Cat.__init__(self, name)>,
#               'shout': <function __main__.Cat.shout(self)>,
#               '__doc__': None})

# %%
Animal.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'x': 123,
#               '__init__': <function __main__.Animal.__init__(self, name)>,
#               'name': <property at 0x6000bd8>,
#               'age': <property at 0x6000c28>,
#               'shout': <function __main__.Animal.shout(self)>,
#               '__dict__': <attribute '__dict__' of 'Animal' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Animal' objects>,
#               '__doc__': None})

# %%
cat.age
# Out:
# 10

# %% [markdown]
# ### 能否覆盖自己的方法

# %%
class Animal:
    def shout(self):
        print('animal shout')
        
class Cat(Animal):
    #覆盖了自身的方法
    def shout(self):
        print('miao')
    #覆盖了自身的方法，显式的调用
    def shout(self):
        print(super())
        print(super(Cat,self))
        super().shout()#等价于super（）
        super(Cat,self).shout()
        self.__class__.__base__.shout(self)# 不推荐

# %%
a=Animal()

# %%
a.shout()
# Out:
# animal shout

# %%
c=Cat()

# %%
c.shout()
# Out:
# <super: <class 'Cat'>, <Cat object>>
# <super: <class 'Cat'>, <Cat object>>
# animal shout
# animal shout
# animal shout

# %%
int.__doc__
# Out:
# "int([x]) -> integer\nint(x, base=10) -> integer\n\nConvert a number or string to an integer, or return 0 if no arguments\nare given.  If x is a number, return x.__int__().  For floating point\nnumbers, this truncates towards zero.\n\nIf x is not a number or if base is given, then x must be a string,\nbytes, or bytearray instance representing an integer literal in the\ngiven base.  The literal can be preceded by '+' or '-' and be surrounded\nby whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.\nBase 0 means to interpret the base from the string as an integer literal.\n>>> int('0b100', base=0)\n4"

# %%
class A:
    def __init__(self,a,d=10):
        self.a=a
        self.__d=d

class B(A):
    def __init__(self,b,c):
        A.__init__(self,b+c,b-c)
        self.b=b
        self.c=c
    def printv(self):
        print(self.b)
        print(self.a)

# %%
f=B(200,300)

# %%
f.__dict__
# Out:
# {'a': 500, '_A__d': -100, 'b': 200, 'c': 300}

# %%
f.printv()
# Out:
# 200
# 500

# %%
def foo(xyz=[],u='abc',z=123):
    xyz=xyz[:]
    xyz.append(1)
    print(xyz)

# %%
foo()
# Out:
# [1]

# %%
print(foo.__defaults__)
# Out:
# ([], 'abc', 123)

# %%
foo([10])
# Out:
# [10, 1]

# %%
class Animal:
    x=123
    def __init__(self,name,age=10):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name,age=20):
        self.__age=age
        self.catname=name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Cat('tom')

# %%
tom.age
# Out:
# 20

# %%
class Animal:
    x=123
    def __init__(self,name,age=10):
        self.name=name
        self.__age=10
    @property
    def name(self):
        return self.name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')
    @classmethod
    def clsmtd(cls):
        print(cls,cls.__name__)
    

class Cat(Animal):
    x='cat'
    def __init__(self,name,age=20):
        self.__age=age
        self.catname=name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('miao')
    @classmethod
    def clsmtd(cls):
        print(cls,cls.__name__)
        print('clstmd')
    

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Carfield('tom')

# %%
tom.name

# %%
tom.name

# %%
tom.clsmtd()#等价于a.__class__.clsmtd()
# Out:
# <class '__main__.Carfield'> Carfield
# clstmd

# %%
class MyClass:
    """A example class"""
    xxx=123 # 类属性
    def foo(self):  #类属性foo，也是方法 self指代当前实例本身
        print('foo')
    #def bar():
        #print('bar')
    @classmethod #类的装饰器,相当于其他的静态方法
    def fnmethod(cls):#cls这个标识符可以是而难以合法名称，但是为了易读不要修改
        cls.height = 170
        print('{}.xxx={}'.format(cls.__name__,cls.xxx))

#在类定义中，使用@classmethod装饰漆修饰的方法
#必须至少有一个参数，且第一个参数留给了cls，cls指代调用者即为类对象自身
#cls这个标识符可以是任意合法的名称，但是为了易读，不要修改
#通过cls可以直接操作类的属性，但是无法通过cls操作类的实例。
    @staticmethod #静态方法
    def staticmtd(a):
        print('static','{}.a={}'.format(MyClass.__name__,a))

# %%
a=MyClass

# %%
class Property:
    def __init__(self, fget, fset=None):
        self.fget = fget
        self.fset = fset
        pass

    def __get__(self, instance, owner):
        if instance is not None:
        #print('p.get', self, instance, owner)
            return self.fget(instance)
        return

    def __set__(self, instance, value):
        if callable(self.fset):
        # print('p.set', instance, value)
            return self.fset(instance, value)
        else:
            raise AttributeError('cant set attribute')
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        super().__init__(name) #与下面方式等价
        #Animal.__init__(self,name)#注意上下两个顺序不一样
        self._name='cat'+name
        self.__age=20
        
    def shout(self):
        print('miao')
        Animal.__init__(self,name)

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat = Cat('tom')
cat.age
# Out:
# 10

# %%
print(cat.__dict__)
# Out:
# {'_name': 'cattom', '_Animal__age': 10, '_Cat__age': 20}

# %%
cat.name
# Out:
# 'cattom'
