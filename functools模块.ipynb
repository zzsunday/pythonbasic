# %%
import inspect
import functools
def add(x,y):
    return x+y
print(inspect.signature(add))
# Out:
# (x, y)

# %%
import inspect
import functools
def add(x,y):
    ret = x+y
    print(ret)
    return x+y
print(inspect.signature(add))
newadd = functools.partial(add,5)(6)
# Out:
# (x, y)
# 11

# %%
print(newadd(4,6))
# Out:
# 10
# 10

# %%
def foo(*args):
    print(args)
foo(1)
# Out:
# (1,)

# %%
def counter():
    count=0
    def inc():
        count=1
        count+=1
        return count
    return inc

# %%
def add(x,y,*args):
    print(args)
    return x+y
add(91,21,x=2,y=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-59814859931b> in <module>
#       2     print(args)
#       3     return x+y
# ----> 4 add(91,21,x=2,y=3)
#
# TypeError: add() got multiple values for argument 'x'

# %%
import functools
import time

@functools.lru_cache()
def add(x,y=5):
    time.sleep(3)
    ret = x+y
    print(ret)
    return ret
add(4)
# Out:
# 9
# 9

# %%
def foo(**kwargs):
    print(kwargs.items())
    for item in 

foo(x=1,y=2,z=3)
# Out:
# dict_items([('x', 1), ('y', 2), ('z', 3)])

# %%
dic={'y':3,'x':1,'z':5}

# %%
sorted(dic.items())
# Out:
# [('x', 1), ('y', 3), ('z', 5)]

# %%
def fib(n):
    if n<2:
        return n
    return fib(n-1)+fib(n-2)

# %%
print([fib(x) for x in range(2)])
# Out:
# [0, 1]

# %%
import functools
@functools.lru_cache()
def fib(n):
    if n<2:
        return n
    return fib(n-1)+fib(n-2)

# %%
isinstance(10,int)
# Out:
# True

# %% [markdown]
# ### 知识盲点

# %%
a={'x':4,'y':6,'z':7}

# %%
b={'c':2,'x':8}

# %%
a.update(b)

# %%
print(a.items())
# Out:
# dict_items([('x', 8), ('y', 6), ('z', 7), ('c', 2)])

# %%
c =tuple(a.items())
# Out:
# (('x', 8), ('y', 6), ('z', 7), ('c', 2))

# %%
for i in c :
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-33af59d384d8> in <module>
# ----> 1 for i in c :
#       2     print(i)
#
# TypeError: 'NoneType' object is not iterable

# %%
from collections import Iterable

# %%
isinstance(c,Iterable)
# Out:
# False

# %%
def foo(x=4,y=5):
    pass

# %%
import inspect

# %%
sig=inspect.signature(foo)

# %%
a=sig.parameters

# %%
a['x'].default
# Out:
# 4

# %% [markdown]
# ### 自己生成一个缓冲器

# %%
import functools
import time
import inspect
import datetime

def s_cache(fn):
    local_cache={}
    @functools.wraps(fn)
    def wrapper(*args,**kwargs):
        # print(args,kwargs)
        key_dict={}#sorted
        sig=inspect.signature(fn)
        dit= sig.parameters#ordereddict
        param_list=list(dit.keys())
        #位置参数
        for i,v in enumerate(args):
            # print(i,v)
            k=param_list[i]
            key_dict[k]=v
        key_dict.update(kwargs)
        for k in dit.keys():
            if k not in key_dict.keys():
                key_dict[k]=dit[k].default
        key=tuple(key_dict.items())
        if key not in local_cache.keys():
            ret = fn(*args, **kwargs)
            local_cache[key]=ret

        return local_cache[key]
    return wrapper
def logger(fn):
    @functools.wraps(fn)
    def wrapper(*args,**kwargs):
        start=datetime.datetime.now()
        ret=fn(*args,**kwargs)
        delta=(datetime.datetime.now()-start).total_seconds()
        print(delta)
        return  ret
    return wrapper
@logger
@s_cache
def add(x,y=5):
    time.sleep(3)
    ret = x+y
    return ret

add(4)
add(4,5)
add(x=4,y=5)
# Out:
# 3.000172
# 0.001
# 0.0
# 9

# %%
a={'x':4,'y':6,'z':7}

# %%
a['g']=2

# %%
a
# Out:
# {'x': 4, 'y': 6, 'z': 7, 'g': 2}

# %%
a['m']=(2,1)

# %%
a
# Out:
# {'x': 4, 'y': 6, 'z': 7, 'g': 2, 'm': (2, 1)}

# %%
a.values()
# Out:
# dict_values([4, 6, 7, 2, (2, 1)])

# %%
a.pop('m')
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-0a8f6359b7e7> in <module>
# ----> 1 a.pop('m')
#       2 a
#
# KeyError: 'm'

# %%
for i,v in a.items():
    print(type(i),type(v))
# Out:
# <class 'str'> <class 'int'>
# <class 'str'> <class 'int'>
# <class 'str'> <class 'int'>
# <class 'str'> <class 'int'>

# %%
b={'x':(1,2),'y':(3,4),'z':(5,6),'h':(7,8),'k':(2,3)}

# %%
for k,(_,ts) in b.items():
    if ts >3:
        b.pop(k)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-124-134d0bd6f2e0> in <module>
# ----> 1 for k,(_,ts) in b.items():
#       2     if ts >3:
#       3         b.pop(k)
#       4
#
# RuntimeError: dictionary changed size during iteration

# %%
c={('x','y'):(4,2),('g','h'):(2,4)}

# %%
cmd=input('>>')
# Out:
# >>fool

# %%
cmd
# Out:
# 'fool   '

# %%
cmd.strip()
# Out:
# 'fool'

# %%
def foo():
     while True:
            cmd=input('>>')
            if cmd == 'quit':
                return
            return 2

# %%
foo()
# Out:
# >>foo1
# 2
