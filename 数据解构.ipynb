# %% [markdown]
# ### 解构：先进行封装为元组，在进行逐一解构

# %%
a,b=1,2 #等价于虾米拿

# %%
c=(1,2)

# %%
a,b=c
print(a,b)
# Out:
# 1 2

# %%
a,b={'d':10,'e':20}
print(a,b)
# Out:
# d e

# %%
lst = list(range(1, 101, 2))
head, *mid, tail = lst

# %%
*lst2 = lst
# Out:
#   File "<ipython-input-12-419bc512b767>", line 4
# SyntaxError: starred assignment target must be in a list or tuple

# %%
lst=[]
for i in range(1):
    row=[1]
    lst.append(row)

# %%
lst
# Out:
# [[1]]
