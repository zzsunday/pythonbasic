# %%
def inc():
    for i in range(5):
        yield i
print(type(inc))
print(type(inc()))
x=inc()
for m in x:
    print(m, '*')
for m in x:
    print(m, '**')
# Out:
# <class 'function'>
# <class 'generator'>
# 0 *
# 1 *
# 2 *
# 3 *
# 4 *

# %%
def gen():
    print('line 1')
    yield 1
    print('line 2')
    yield 2
    print('line 3')
    return 3
next(gen()) # line 1
next(gen()) # line 1
print("*************************")
g = gen()
print(next(g)) # line 1
print(next(g)) # line 2
print(g,next(g)) # StopIteration
print(next(g, 'End')) # ?????????
# Out:
# line 1
# line 1
# *************************
# line 1
# 1
# line 2
# 2 <generator object gen at 0x0000000005ADF750>
# line 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-0fce82b060f8> in <module>
#      12 print(next(g)) # line 1
#      13 print(next(g),g) # line 2
# ---> 14 print(g,next(g)) # StopIteration
#      15 print(next(g, 'End')) # ?????????
#
# StopIteration: 3

# %%
def inc():
    for i in range(5):
        yield i

# %%
print(type(inc))
print(type(inc()))
# Out:
# <class 'function'>
# <class 'generator'>

# %%
x=inc()
print(type(x))
print(next(x))
# Out:
# <class 'generator'>
# 0

# %%
for m in x:
    print(m,"*")
# Out:
# 1 *
# 2 *
# 3 *
# 4 *

# %%
for m in x :
    print(m,"**")

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-9-92de4e9f6b1e> in <module>
# ----> 1 next(x)
#
# StopIteration:

# %%
y=[i for i in range(5)]

# %%
y
# Out:
# [0, 1, 2, 3, 4]

# %%
y=(i for i in range(5))

# %%
next(y)
# Out:
# 0

# %%
def gen():
    print('line 1')
    yield 1
    print('line 2')
    yield 2
    print('line 3')
    return 3
next(gen()) # line 1
next(gen()) # line 1
g = gen()
print(next(g)) # line 1
print(next(g)) # line 2
#print(next(g)) # StopIteration
print(next(g, 'End')) # 'End'相当于一个用end给yield返回值
# Out:
# line 1
# line 1
# line 1
# 1
# line 2
# 2
# line 3
# End

# %%
c=[0]

# %%
c[0]+=1
c
# Out:
# [1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def inc():
    def counter():
        i = 0
        while True:
            i += 1
            yield i
    c = counter()
    return lambda : next(c)
foo = inc()
print(foo())
print(foo())
# Out:
# 1
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def inc():
    yield from range(1000)
foo=inc()
print(next(foo))
print(next(foo))
print(next(foo))
# Out:
# 0
# 1
# 2

# %%
def counter(n): # ???????
    for x in range(n):
        yield x
def inc(n):
    yield from counter(n)
foo = inc(10)
print(next(foo))
print(next(foo))
# Out:
# 0
# 1

# %%
lst=[]
for i,v in enumerate(lst):
    print(i,v)
