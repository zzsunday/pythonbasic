# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
tom=Cat('tom')
print(tom.name)
print(tom.shout())
# Out:
# tom
# miao
# None

# %%
tom.__dict__
# Out:
# {'_name': 'tom', '_Animal__age': 10}

# %%
jerry=Animal('jerry')

# %%
jerry.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10}

# %%
jerry._Animal__age
# Out:
# 10

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        Animal.__init__(self,name)
        self.catname=name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')

# %%
cat.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10, 'catname': 'jerry'}

# %%
cat.name
# Out:
# 'jerry'

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        Animal.__init__(self,name)
        self._name='cat'+name
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'catjerry', '_Animal__age': 10}

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        self._name='cat'+name
        Animal.__init__(self,name)#注意上下两个顺序不一样
    def shout(self):
        print('miao')

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10}

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        self._name='cat'+name
        Animal.__init__(self,name)#注意上下两个顺序不一样
    def shout(self):
        print('miao')
        Animal.__init__(self,name)

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
# Out:
# {'_name': 'jerry', '_Animal__age': 10}

# %%
cat.shout()
# Out:
# miao
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-947507a6faa6> in <module>
# ----> 1 cat.shout()
#
# <ipython-input-40-87fe4382047b> in shout(self)
#      17     def shout(self):
#      18         print('miao')
# ---> 19         Animal.__init__(self,name)
#      20
#      21 class Carfield(Cat):
#
# NameError: name 'name' is not defined

# %%
class Animal:
    x=123
    def __init__(self,name):
        self._name=name
        self.__age=10
    @property
    def name(self):
        return self._name
    @property
    def age(self):
        return self.__age
    def shout(self):
        print('animal shout')

class Cat(Animal):
    x='cat'
    def __init__(self,name):
        Animal.__init__(self,name)#注意上下两个顺序不一样
        self._name='cat'+name
        self.__age=20
        
    def shout(self):
        print('miao')
        Animal.__init__(self,name)

class Carfield(Cat):
    pass

class PersiaCat(Cat):
    pass

class Dog(Animal):
    def run(self):
        print('dog run')

# %%
cat=Cat('jerry')
cat.__dict__
