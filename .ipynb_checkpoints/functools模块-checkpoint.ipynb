# %%
import inspect
import functools
def add(x,y):
    return x+y
print(inspect.signature(add))
# Out:
# (x, y)

# %%
import inspect
import functools
def add(x,y):
    ret = x+y
    print(ret)
    return x+y
print(inspect.signature(add))
newadd = functools.partial(add,5)(6)
# Out:
# (x, y)
# 11

# %%
print(newadd(4,6))
# Out:
# 10
# 10

# %%
def foo(*args):
    print(args)
foo(1)
# Out:
# (1,)

# %%
def counter():
    count=0
    def inc():
        count=1
        count+=1
        return count
    return inc

# %%
def add(x,y,*args):
    print(args)
    return x+y
add(91,21,x=2,y=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-59814859931b> in <module>
#       2     print(args)
#       3     return x+y
# ----> 4 add(91,21,x=2,y=3)
#
# TypeError: add() got multiple values for argument 'x'

# %%
import functools
import time

@functools.lru_cache()
def add(x,y=5):
    time.sleep(3)
    ret = x+y
    print(ret)
    return ret
add(4)
# Out:
# 9
# 9

# %%
def foo(**kwargs):
    print(kwargs.items())
    for item in 

foo(x=1,y=2,z=3)
# Out:
# dict_items([('x', 1), ('y', 2), ('z', 3)])

# %%
dic={'y':3,'x':1,'z':5}

# %%
sorted(dic.items())
# Out:
# [('x', 1), ('y', 3), ('z', 5)]

# %%
lst=[]
