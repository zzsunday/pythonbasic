# %%
lst = ['1','2','3']
print("\"".join(lst)) # 分隔符是双引号
print(" ".join(lst))
# Out:
# 1"2"3
# 1 2 3

# %%
print("\n".join(lst))
# Out:
# 1
# 2
# 3

# %%
lst = ['1',['a','b'],'3']
print(" ".join(lst))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5af3a8f68369> in <module>
#       1 lst = ['1',['a','b'],'3']
# ----> 2 print(" ".join(lst))
#
# TypeError: sequence item 1: expected str instance, list found

# %%
lst = ['1','2','3']

# %%
lst.remove('2')

# %%
lst
# Out:
# ['1', '3']

# %%
s = "\r \n \t Hello Python \n \t"
print(s)
# Out:
#  	 Hello Python

# %%
s.strip()
# Out:
# 'Hello Python'

# %%
import math
print(math.ceil(45.16))
print(math.floor(45.16))
# Out:
# 46
# 45

# %%
bytes('abc','utf8')
# Out:
# b'abc'

# %%
a='abc'.encode()
a.decode()
# Out:
# 'abc'

# %%
a='abc'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9338c2ed236c> in <module>
# ----> 1 size(a)
#
# NameError: name 'size' is not defined

# %%
b=bytes(a)
b
# Out:
# b'abc'

# %%
id(b) is id(a)
# Out:
# False

# %%
id(a)
# Out:
# 122923048

# %%
id(b)
# Out:
# 122923048

# %%
'abc'.encode().hex()
# Out:
# '616263'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-b729cba90221> in <module>
# ----> 1 bytes(10,12)
#
# TypeError: bytes() argument 2 must be str, not int

# %%
# Out:
#   File "<ipython-input-76-32c2c4ecc585>", line 1
#     99.encode().hex()
#             ^
# SyntaxError: invalid syntax

# %%
b=bytearray()

# %%
b.append(97)

# %%
type(b)
# Out:
# bytearray

# %%
b.decode()
# Out:
# 'a'

# %%
b'abccde'[2]
# Out:
# 99
