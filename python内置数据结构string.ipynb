# %%
s5 = r"hello \n magedu.com"
s5
# Out:
# 'hello \\n magedu.com'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0381d5a34a34> in <module>
#       1 lst = ['1',['a','b'],'3']
# ----> 2 print(":: ".join(lst))#第二个数据类型为引用类型，要求必须都是字符串
#
# TypeError: sequence item 1: expected str instance, list found

# %%
s1 = "I'm \ta super student."
s1.split()
# Out:
# ["I'm", 'a', 'super', 'student.']

# %%
s1.split('s')
# Out:
# ["I'm \ta ", 'uper ', 'tudent.']

# %%
s1.split('super')
# Out:
# ["I'm \ta ", ' student.']

# %%
s1.split('super ')
# Out:
# ["I'm \ta ", 'student.']

# %%
'ab c\n\nde fg\rkl\r\n'.splitlines(True)
# Out:
# ['ab c\n', '\n', 'de fg\r', 'kl\r\n']

# %%
'ab c\n\nde fg\rkl\r\n'.splitlines()
# Out:
# ['ab c', '', 'de fg', 'kl']

# %%
s1 = '''I'm a super student.
You're a super teacher.'''
print(s1)
# Out:
# I'm a super student.
# You're a super teacher.

# %%
print(s1.splitlines())
# Out:
# ["I'm a super student.", "You're a super teacher."]

# %%
print(s1.splitlines(True))
# Out:
# ["I'm a super student.\n", "You're a super teacher."]

# %% [markdown]
# ### 字符串分割*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1 = "I'm a super student."
s1.partition('s')
# Out:
# ("I'm a ", 's', 'uper student.')

# %%
s1.partition(' ') #注意返回的是一个元组
# Out:
# ("I'm", ' ', 'a super student.')

# %%
s1.rpartition('abc')
# Out:
# ('', '', "I'm a super student.")

# %% [markdown]
# ### 字符串修改*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str1='www.magedu.com'.replace('w','p')#返回一个新的字符串，不是原处修改

# %%
str1
# Out:
# 'ppp.magedu.com'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = " I am very very very sorry  "

# %%
s.strip('Iy')
# Out:
# ' I am very very very sorry  '

# %%
s.strip('Iy ')
# Out:
# 'am very very very sorr'

# %%
s.strip('y rIam')
# Out:
# 'very very very so'

# %%
s.strip('y rIamso')
# Out:
# 'very very ve'

# %%
s.strip('r yIamsove')
# Out:
# ''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "I am very very very sorry"

# %%
s.find('xxx',20)#没找到返回-1
# Out:
# -1

# %%
s.rfind('very',-10,-1)
# Out:
# 15

# %%
s.rfind('y',-1)
# Out:
# 24

# %%
s.rfind('xxx',20)#-1代表没找着
# Out:
# -1

# %%
s.rfind('very',-10,-1)#从-10到-1的字符串取出来，然后再进行find
# Out:
# 15

# %% [markdown]
# #### 字符串连接

# %%
lst = ['1','2','3']
print("\"".join(lst)) # 分隔符是双引号
print(" ".join(lst))
print("\n".join(lst))
print("".join(lst))
# Out:
# 1"2"3
# 1 2 3
# 1
# 2
# 3
# 123

# %%
a="\n".join(lst)
a
# Out:
# '1\n2\n3'

# %%
lst1 = ['1',['a','b'],'3']
print(" ".join(lst1))
lst = ['1',['a','b'],'3']
print(":: ".join(lst))#第二个数据类型为引用类型，要求必须都是字符串
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d6bdd3c2fbc5> in <module>
#       1 lst1 = ['1',['a','b'],'3']
# ----> 2 print(" ".join(lst1))
#
# TypeError: sequence item 1: expected str instance, list found

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s.startswith('very')
# Out:
# False

# %%
i=0
for x in s:
    print(str(i)+x,end=' ')
    i+=1
# Out:
# 0I 1  2a 3m 4  5v 6e 7r 8y 9  10v 11e 12r 13y 14  15v 16e 17r 18y 19  20s 21o 22r 23r 24y

# %%
s.startswith('very', 5, 9)
# Out:
# True

# %%
s.endswith('very', 5, 9)
# Out:
# True

# %%
s.endswith('sorry', 5, -1)
# Out:
# False

# %%
s.endswith('sorry', 5, 100)
# Out:
# True

# %%
from collections import namedtuple

# %%
Point=namedtuple('Point','x y')

# %%
p=Point(4,5)

# %%
'{{{0.x},{0.y}}}'.format(p)
# Out:
# '{4,5}'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'{0}*{1}={2}'.format(3,2,2*3)
# Out:
# '3*2=6'

# %%
'{0}*{1}={2:<02}'.format(3,2,2*3)
# Out:
# '3*2=60'

# %%
'{0}*{1}={2:<2}'.format(3,2,2*3)
# Out:
# '3*2=6 '

# %%
'{0}*{1}={2:>02}'.format(3,2,2*3)
# Out:
# '3*2=06'

# %%
hex(192)
# Out:
# '0xc0'

# %%
hex(168)
# Out:
# '0xa8'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m=input('>>').strip().lstrip('0')
for i in range(len(m)):
    print('{} count ={}'.format(m[i],m.count(m[i])))
# Out:
# >>12345
# 1 count =1
# 2 count =1
# 3 count =1
# 4 count =1
# 5 count =1

# %%
a='0123'
a=int(a)
a
# Out:
# 123

# %%
inputlist=input('>>').split(' ')
# Out:
# >>12 23 45 1 35

# %%
inputlist
# Out:
# ['12', '23', '45', '1', '35']

# %%
lst=[]
for i in range(5):
    m = input('>>>').strip().lstrip('0')
    lst.append(int(m))
print(lst)
print(lst.sort())
print(sorted(lst))
# Out:
# >>>12
# >>>33
# >>>2
# >>>23
# >>>99
# [12, 33, 2, 23, 99]
# None
# [2, 12, 23, 33, 99]

# %%
lst=[12, 33, 2, 23, 99]

# %%
lst.sort()

# %%
lst
# Out:
# [2, 12, 23, 33, 99]

# %%
lst1=[12, 33, 2, 23, 99]

# %%
a=sorted(lst1)

# %%
a
# Out:
# [2, 12, 23, 33, 99]

# %%
t\
